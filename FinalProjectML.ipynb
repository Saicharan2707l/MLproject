# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# !pip install -q xlrd

# %%
df = pd.read_excel("Warfarin_Dose_Prediction_Modified.xls", 'Subject Data')

# %%
df.head()
# Out:
#    Gender Race (Reported)      Age  Height (cm)  Weight (kg)  Diabetes  \
# 0    male           White  60 - 69      193.040        115.7       NaN
# 1  female           White  50 - 59      176.530        144.2       NaN
# 2  female           White  40 - 49      162.560         77.1       NaN
# 3    male           White  60 - 69      182.245         90.7       NaN
# 4    male           White  50 - 59      167.640         72.6       NaN
#
#                                     Medications  Simvastatin (Zocor)  \
# 0      aspirin; not simvastatin; not amiodarone                  0.0
# 1  not aspirin; not simvastatin; not amiodarone                  0.0
# 2  not aspirin; not simvastatin; not amiodarone                  0.0
# 3  not aspirin; not simvastatin; not amiodarone                  0.0
# 4  not aspirin; not simvastatin; not amiodarone                  0.0
#
#    Atorvastatin (Lipitor)  Amiodarone (Cordarone)  Target INR  \
# 0                     NaN                     0.0         2.5
# 1                     NaN                     0.0         2.5
# 2                     NaN                     0.0         2.5
# 3                     NaN                     0.0         2.5
# 4                     NaN                     0.0         2.5
#
#    Therapeutic Dose of Warfarin  INR on Reported Therapeutic Dose of Warfarin  \
# 0                          49.0                                          2.60
# 1                          42.0                                          2.15
# 2                          53.0                                          1.90
# 3                          28.0                                          2.40
# 4                          42.0                                          1.90
#
#   Cyp2C9 genotypes  \
# 0            *1/*1
# 1            *1/*1
# 2            *1/*1
# 3            *1/*1
# 4            *1/*3
#
#   VKORC1 genotype: -1639 G>A (3673); chr16:31015190; rs9923231; C/T
# 0                                                A/G
# 1                                                A/A
# 2                                                G/G
# 3                                                A/G
# 4                                                A/G

# %%
df.columns
# Out:
# Index(['Gender', 'Race (Reported)', 'Age', 'Height (cm)', 'Weight (kg)',
#        'Diabetes', 'Medications', 'Simvastatin (Zocor)',
#        'Atorvastatin (Lipitor)', 'Amiodarone (Cordarone)', 'Target INR',
#        'Therapeutic Dose of Warfarin',
#        'INR on Reported Therapeutic Dose of Warfarin', 'Cyp2C9 genotypes',
#        'VKORC1 genotype: -1639 G>A (3673); chr16:31015190; rs9923231; C/T'],
#       dtype='object')

# %%
#Converting Categorical text data into numerical
from sklearn.preprocessing import LabelEncoder

# Create a label encoder object
le = LabelEncoder()

# Convert the categorical columns with the LabelEncoder
for column in df.columns:
    if df[column].dtype == 'object':
        df[column] = le.fit_transform(df[column].astype(str))

df.head()
# Out:
#    Gender  Race (Reported)  Age  Height (cm)  Weight (kg)  Diabetes  \
# 0       1               20    5      193.040        115.7       NaN
# 1       0               20    4      176.530        144.2       NaN
# 2       0               20    3      162.560         77.1       NaN
# 3       1               20    5      182.245         90.7       NaN
# 4       1               20    4      167.640         72.6       NaN
#
#    Medications  Simvastatin (Zocor)  Atorvastatin (Lipitor)  \
# 0         1029                  0.0                     NaN
# 1         1791                  0.0                     NaN
# 2         1791                  0.0                     NaN
# 3         1791                  0.0                     NaN
# 4         1791                  0.0                     NaN
#
#    Amiodarone (Cordarone)  Target INR  Therapeutic Dose of Warfarin  \
# 0                     0.0         2.5                          49.0
# 1                     0.0         2.5                          42.0
# 2                     0.0         2.5                          53.0
# 3                     0.0         2.5                          28.0
# 4                     0.0         2.5                          42.0
#
#    INR on Reported Therapeutic Dose of Warfarin  Cyp2C9 genotypes  \
# 0                                          2.60                 0
# 1                                          2.15                 0
# 2                                          1.90                 0
# 3                                          2.40                 0
# 4                                          1.90                 5
#
#    VKORC1 genotype: -1639 G>A (3673); chr16:31015190; rs9923231; C/T
# 0                                                  1
# 1                                                  0
# 2                                                  2
# 3                                                  1
# 4                                                  1

# %%
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# Gender                                                                  0
# Race (Reported)                                                         0
# Age                                                                     0
# Height (cm)                                                          1146
# Weight (kg)                                                           287
# Diabetes                                                             2417
# Medications                                                             0
# Simvastatin (Zocor)                                                  1839
# Atorvastatin (Lipitor)                                               3245
# Amiodarone (Cordarone)                                               1518
# Target INR                                                           4441
# Therapeutic Dose of Warfarin                                          172
# INR on Reported Therapeutic Dose of Warfarin                          732
# Cyp2C9 genotypes                                                        0
# VKORC1 genotype: -1639 G>A (3673); chr16:31015190; rs9923231; C/T       0
# dtype: int64

# %%
#Missing value treatment
from sklearn.impute import SimpleImputer, MissingIndicator

# Technique 1: Impute the mean for all missing values in a variable
# For numerical columns
for column in df.select_dtypes(include=['int64', 'float64']).columns:
    df[column].fillna(df[column].mean(), inplace=True)

# For categorical columns
for column in df.select_dtypes(include=['object']).columns:
    df[column].fillna(df[column].mode()[0], inplace=True)

# Technique 2: Using Missingness Indicator Variable (MIV) to handle missingness
# Create a new variable that is an indicator of missingness
indicator = MissingIndicator(features='missing-only')
mis_ind = indicator.fit_transform(df)

# Add the indicator to the dataframe
for i, column in enumerate(indicator.features_):
    df[column + '_missing'] = mis_ind[:, i]

df.head()
# Out:
#    Gender  Race (Reported)  Age  Height (cm)  Weight (kg)  Diabetes  \
# 0       1               20    5      193.040        115.7  0.187024
# 1       0               20    4      176.530        144.2  0.187024
# 2       0               20    3      162.560         77.1  0.187024
# 3       1               20    5      182.245         90.7  0.187024
# 4       1               20    4      167.640         72.6  0.187024
#
#    Medications  Simvastatin (Zocor)  Atorvastatin (Lipitor)  \
# 0         1029                  0.0                0.089613
# 1         1791                  0.0                0.089613
# 2         1791                  0.0                0.089613
# 3         1791                  0.0                0.089613
# 4         1791                  0.0                0.089613
#
#    Amiodarone (Cordarone)  Target INR  Therapeutic Dose of Warfarin  \
# 0                     0.0         2.5                          49.0
# 1                     0.0         2.5                          42.0
# 2                     0.0         2.5                          53.0
# 3                     0.0         2.5                          28.0
# 4                     0.0         2.5                          42.0
#
#    INR on Reported Therapeutic Dose of Warfarin  Cyp2C9 genotypes  \
# 0                                          2.60                 0
# 1                                          2.15                 0
# 2                                          1.90                 0
# 3                                          2.40                 0
# 4                                          1.90                 5
#
#    VKORC1 genotype: -1639 G>A (3673); chr16:31015190; rs9923231; C/T
# 0                                                  1
# 1                                                  0
# 2                                                  2
# 3                                                  1
# 4                                                  1

# %%
#checking missing values after treatment
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# Gender                                                               0
# Race (Reported)                                                      0
# Age                                                                  0
# Height (cm)                                                          0
# Weight (kg)                                                          0
# Diabetes                                                             0
# Medications                                                          0
# Simvastatin (Zocor)                                                  0
# Atorvastatin (Lipitor)                                               0
# Amiodarone (Cordarone)                                               0
# Target INR                                                           0
# Therapeutic Dose of Warfarin                                         0
# INR on Reported Therapeutic Dose of Warfarin                         0
# Cyp2C9 genotypes                                                     0
# VKORC1 genotype: -1639 G>A (3673); chr16:31015190; rs9923231; C/T    0
# dtype: int64

# %%
import numpy as np

# Construct the feature dataset (X) and label variable (Y)
X = df.drop('Therapeutic Dose of Warfarin' , axis=1).values
Y = df['Therapeutic Dose of Warfarin'].values

# Save them into numpy variables
np.save('X.npy', X)
np.save('Y.npy', Y)
